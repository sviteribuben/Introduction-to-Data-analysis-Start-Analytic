# %% [markdown]
# <a href="https://colab.research.google.com/github/sviteribuben/skillbox/blob/master/OLD_matplotlib_hw_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Готовим данные для домашки

# %%
import pandas as pd
from datetime import datetime

air_df = pd.read_csv('./data/air_quality.tar.gz', compression='gzip', sep=';', encoding='utf8')
air_df = air_df[air_df.iloc[:,0].notnull()]

# формируем 
air_df['ts'] = (air_df.iloc[:,0]+ ' ' + air_df.iloc[:,1]).map(
    lambda x: datetime.strptime(x.replace('.',':'), "%d/%m/%Y %H:%M:%S")
)

air_df.head(5)
# Out:
#   air_quality.csv      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0      10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1      10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2      10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3      10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4      10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH                  ts
# 0  13,6  48,9  0,7578 2004-03-10 18:00:00
# ...

# %% [markdown]
# # Визуализация данных с помощью matplotlib
#
# ## 1. Чтение текстовых файлов, файловые дескрипторы
#
# ### 1.1
#
# **Простая задача** Выберите любой показатель загрязнённости воздуха (кроме NOx(GT), его мы использовали в туториале) и постройте график по 30 последним доступным наблюдениям.
#
# *Результат выполнения*
#
# Должен получиться такой же график, как для NOx(GT) (из второго урока данного модуля).
# ![title](https://248006.selcdn.ru/public/Data-science-2/img/PearsonFig.jpg)

# %%
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import register_matplotlib_converters
# %matplotlib inline

register_matplotlib_converters()
TOP = 30

fig, subplot = plt.subplots()
# формируем значения по оси  X
x_ticks = air_df['ts'].values[-TOP:]
# формируем значения по оси Y
y_ticks = air_df['CO(GT)'].values[-TOP:]
# график функции
subplot.plot(x_ticks, y_ticks)
# подписываем график
subplot.set_title('CO(GT) concentrainon by date' , fontsize=22)
subplot.set_ylabel('CO(GT)')
x_labels = [pd.to_datetime(str(i)).strftime("%m.%d %H:%M") for i in air_df['ts'].values[-TOP:]]
# добавляем подписи к осям
plt.xticks(x_ticks, rotation='70', labels=x_labels)

plt.show()

# %% [markdown]
# ### 1.2
#
# **Задание среднего уровня** Постройте scatter plot между выбранным вами показателем и температурой (содержится в столбце `air_df['T]`).

# %%
register_matplotlib_converters()
TOP=30

fig, subplot = plt.subplots()
# формируем значения по оси  X
x_ticks = air_df['CO(GT)'].values[-TOP:]
# формируем значения по оси Y
y_ticks = air_df['T'].values[-TOP:]
# график функции
subplot.scatter(x_ticks, y_ticks,
               c = 'r', 
               s = 50,
               marker="s",
                label='Зависимость CO от T')
# подписываем график
subplot.set_title('CO(GT) sc by date', fontsize=22)
subplot.set_ylabel('T')
subplot.set_xlabel('CO(GT)')
fig.set_figwidth(8)
fig.set_figheight(8)
plt.legend(loc='lower right', fontsize=14)

plt.show()

# %% [markdown]
# ### 1.3
#
# **Задание высокого уровня** Аналогично тому, как мы строили два графика рядом, отобразите на одном полотне следующие 4 графика:
# <pre>
# ['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)'].
# </pre>
# По каждому показателю учитывайте только последние 30 наблюдений. Значения оси X используйте из столбца T.
#
# *Ожидаемый результат*
#
# ![title](https://248006.selcdn.ru/public/Data-science-2/img/four_pack.png)

# %%
TOP=30

fig = plt.figure(figsize=(20,10))

fig.set_figwidth(12)
fig.set_figheight(8)
subplot1 = fig.add_subplot(2, 2, 1)
subplot1.plot(air_df['T'].values[-TOP:],
             air_df['PT08.S1(CO)'].values[-TOP:], linewidth = 3)

subplot2 = fig.add_subplot(2, 2, 2)
subplot2.plot(air_df['T'].values[-TOP:],
             air_df['NMHC(GT)'].values[-TOP:],
             linewidth = 3)

subplot3 = fig.add_subplot(2, 2, 3)
subplot3.plot(air_df['T'].values[-TOP:],
             air_df['C6H6(GT)'].values[-TOP:],
             linewidth = 3)

subplot4 = fig.add_subplot(2, 2, 4)
subplot4.plot(air_df['T'].values[-TOP:],
             air_df['PT08.S2(NMHC)'].values[-TOP:],
             linewidth = 3)

# subplot1.yticks([800, 1000, 1200, 1400])
# subplot2.yticks([190, 200, 210, 220])
# subplot3.yticks([4.1, 5, 5.5, 6])
# subplot4.yticks([500, 750, 1000, 1250])

# subplot1.set_ylim(800, 1400)
# subplot2.set_ylim(190, 210)
# subplot3.set_ylim(3, 12)
# subplot4.set_ylim(400, 1300)
# subplot3.set_xticks(x)
# subplot3.set_yticks(air_df['T']) 


plt.show()
