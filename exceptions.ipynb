# %% [markdown]
# <a href="https://colab.research.google.com/github/sviteribuben/skillbox/blob/master/exceptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Исключения
# ## Домашняя работа

# %% [markdown]
# ### Вопросы по лекциям.

# %% [markdown]
# Как поймать вообще все ошибки, которые могут произойти?

# %% [markdown]
# **Ответ:**<br> при использовании `try/except` при выводе except - не указать какой тип исключения "ловим"

# %% [markdown]
# Сколько раз подряд можно указывать except?

# %% [markdown]
# **Ответ:**<br> `except` можно указывать бесконечное количество раз, в зависимости от задачи

# %% [markdown]
# Вы хотите с помощью print вывести название ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**
# <br> для этого необходимо в блоке except объявить объект исключения как переменную и распечатать его <br>(`except NameError as ne:
# print(ne)`)

# %% [markdown]
# Вы хотите с помощью print вывести параметры ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**<br>указать на объект исключения (exc) и распечатать его аргументы (exc.args)

# %% [markdown]
# Что такое DeprecationWarning?

# %% [markdown]
# **Ответ:**<br> Это потомок базового класса `Warning`, говорящий о том что в существующем релизе библиотеки все еще работает, но в следующих релизах будут внесены изменения функционала

# %% [markdown]
# ### Разминочные задания.
# <br>
#
# Вам даны две функции. Поисследуйте, какие ошибки могут возникнуть при их реализации. Обработайте эти ошибки.

# %%
def div():
    for i in range(2):
        x = int(input("enter a number: "))
        y = int(input("enter another number: "))
        print(x, '/', y, '=', x/y)
        
try:
    goto = div()
    print(goto)
except (ZeroDivisionError, ValueError) as exc:
    print(f'поймали исключение - {exc}')
# можно также расписать отдельное исключение
# Out:
# enter a number: 12
# enter another number: 11.2
# поймали исключение - invalid literal for int() with base 10: '11.2'

# %%
def sumOfPairs(L1, L2):
    sum = 0
    sumOfPairs = []
    for i in range(len(L1)):
        sumOfPairs.append(L1[i]+L2[i])

    print("sumOfPairs = ", sumOfPairs)

try:
    goto = sumOfPairs('10', '0')
    print(goto)
except IndexError as exc:
    print(f'IndexError поймали исключение - {exc}')
except TypeError as texc:
    print(f'TypeError поймали исключение - {texc}')
# Out:
# IndexError поймали исключение - string index out of range

# %% [markdown]
# ### Задание 1.
#
# Есть файл с протоколом регистраций пользователей на сайте (registrations.txt).<br>
# Каждая строка содержит информацию о имени, электронной почте и возрасте человека. <br><br>
#
#
# Надо проверить данные из файла, для каждой строки:
#  - присутсвуют все три поля
#  - поле имени содержит только буквы
#  - поле email содержит @ и .
#  - поле возраст является числом от 10 до 99<br>
#
# В результате проверки нужно сформировать два файла
#  - registrations_good.log для правильных данных, записывать строки как есть
# - registrations_bad.log для ошибочных, записывать строку и вид ошибки.<br>
#
# Для валидации строки данных написать метод, который может выкидывать исключения:
#  - НЕ присутсвуют все три поля: ValueError
#  - поле имени содержит НЕ только буквы: NotNameError (кастомное исключение)
#  - поле email НЕ содержит @ и .(точку): NotEmailError (кастомное исключение)
#  - поле возраст НЕ является числом от 10 до 99: ValueError
# Вызов метода обернуть в try-except.

# %%
class NotNameError(Exception):
    pass


class NotEmailError(Exception):
    pass


with open('registrations_.txt', 'r', encoding='utf-8') as ff:
    for line in ff:
        print(f'Read line {line}')
        try:
            name, email, age, = line.split(' ')
            name = str(name)
            email = str(email)
            age = int(age)
            with open('registrations_bad.log', 'a', encoding='utf-8') as fff:
                try:
                    if name.isalpha() is False:
                        raise NotNameError(f'{name} содержит не буквы')  # NotNameError (кастомное исключение)
                        fff.write(line)
                    elif age < 10 or age > 99:
                        raise ValueError(f'{age} не правильный возраст') # поле возраст НЕ является числом от 10 до 99:ValueError 
                        fff.write(line)
                    elif '@' and '.' not in email:
                        raise NotEmailError(f'{email} не правильный email') # NotEmailError (кастомное исключение)
                        fff.write(line)
                    else:
                        print(f'{name} {email} {age} - Все значения валидны')
                        with open('registrations_good.log', 'a', encoding='utf-8') as f:
                            f.write(line)

    
                except (NotNameError, NotEmailError, ValueError) as exc:
                    print(f'Поймали {exc}')
                continue

        except ValueError as exc:
            print(f'Поймали ValueError - НЕ ВСЕ ЗНАЧЕНИЯ {exc}... Продолжаем')#НЕ присутсвуют все три поля: ValueError
        continue
# Out:
# Read line Ольга rin@mail.ru 45
#
# Ольга rin@mail.ru 45 - Все значения валидны
# Read line Артём knkjmbwwe@gmail.com 40
#
# Артём knkjmbwwe@gmail.com 40 - Все значения валидны
# Read line Нагиев kptvmbjlrs@gmail.com 81
#
# Нагиев kptvmbjlrs@gmail.com 81 - Все значения валидны
# Read line Пенг zrlddzogc@mail.ru 20
#
# Пенг zrlddzogc@mail.ru 20 - Все значения валидны
# Read line Сянцзян swnjvpt@gmail.com 49
#
# Сянцзян swnjvpt@gmail.com 49 - Все значения валидны
# Read line Степан omsgoxfhv@ya.ru 69
#
# Степан omsgoxfhv@ya.ru 69 - Все значения валидны
# Read line Владимир opsr@gmail.com 45
#
# Владимир opsr@gmail.com 45 - Все значения валидны
# Read line Ван mrv@gmail.com 82
#
# Ван mrv@gmail.com 82 - Все значения валидны
# Read line Чонгкун pkz@mail.ru 18
#
# Чонгкун pkz@mail.ru 18 - Все значения валидны
# Read line Равшан nryx@ya.ru 84
#
# Равшан nryx@ya.ru 84 - Все значения валидны
# Read line Волочкова hynhkchl@mail.ru 93
#
# Волочкова hynhkchl@mail.ru 93 - Все значения валидны
# ...
